# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup" data-toc-modified-id="Setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup</a></span></li><li><span><a href="#Working-with-Text" data-toc-modified-id="Working-with-Text-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Working with Text</a></span><ul class="toc-item"><li><span><a href="#String-split" data-toc-modified-id="String-split-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>String split</a></span></li><li><span><a href="#String-replacement" data-toc-modified-id="String-replacement-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>String replacement</a></span></li><li><span><a href="#Substrings" data-toc-modified-id="Substrings-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Substrings</a></span></li><li><span><a href="#Pattern-matching" data-toc-modified-id="Pattern-matching-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Pattern matching</a></span></li></ul></li><li><span><a href="#Time-Series" data-toc-modified-id="Time-Series-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Time Series</a></span><ul class="toc-item"><li><span><a href="#Timestamps-and-Time-Spans" data-toc-modified-id="Timestamps-and-Time-Spans-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Timestamps and Time Spans</a></span></li><li><span><a href="#Converting-to-Timestamps" data-toc-modified-id="Converting-to-Timestamps-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Converting to Timestamps</a></span></li><li><span><a href="#Time/data-components" data-toc-modified-id="Time/data-components-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Time/data components</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Working with Text

# %% [markdown]
# ## String split

# %%
D = {
    "id": [0, 1, 2],
    "s": ["a_b", "B_d", "g_H"]
}
DF = pd.DataFrame(D)

# %%
DF
# Out:
#    id    s
# 0   0  a_b
# 1   1  B_d
# 2   2  g_H

# %%
# substring occurring before the split
DF.loc[:, "s0"] = DF["s"].str.split("_").str.get(0)

# %%
# substring occurring after the split
DF.loc[:, "s1"] = DF["s"].str.split("_").str.get(1)

# %%
DF
# Out:
#       s s_1 s0 s1
# id
# 0   a_b   a  a  b
# 1   B_d   B  B  d
# 2   g_H   g  g  H

# %%
# expand option
DF.set_index("id", inplace=True)
DF0 = DF["s"].str.split("_", expand=True)
DF0
# Out:
#     0  1
# id
# 0   a  b
# 1   B  d
# 2   g  H

# %%
# change var names
DF0.rename(columns={0: "s_0", 1: "s_1"}, inplace=True)
DF0
# Out:
#    s_0 s_1
# id
# 0    a   b
# 1    B   d
# 2    g   H

# %%
# remove some junk in the DF
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 0 to 2
# Data columns (total 4 columns):
# s      3 non-null object
# s_1    3 non-null object
# s0     3 non-null object
# s1     3 non-null object
# dtypes: object(4)
# memory usage: 200.0+ bytes

# %%
DF.drop(["s_1", "s0", "s1"], axis=1, inplace=True)
DF
# Out:
#       s
# id
# 0   a_b
# 1   B_d
# 2   g_H

# %%
# merge DF and DF0
DF = pd.merge(DF, DF0, left_index=True, right_index=True)
DF
# Out:
#       s s_0 s_1
# id
# 0   a_b   a   b
# 1   B_d   B   d
# 2   g_H   g   H

# %% [markdown]
# ## String replacement

# %%
DF.loc[:,'s_2'] = DF["s"].str.replace("_", "--")

# %%
DF
# Out:
#       s s_0 s_1   s_2
# id
# 0   a_b   a   b  a--b
# 1   B_d   B   d  B--d
# 2   g_H   g   H  g--H

# %% [markdown]
# ## Substrings

# %% [markdown]
# Tutorial on regular expressions:
# https://www.w3schools.com/jsref/jsref_obj_regexp.asp

# %%
DF["s"].str.extract("(?P<letter>[A-Z])")
# Out:
#    letter
# id
# 0     NaN
# 1       B
# 2       H

# %% [markdown]
# ## Pattern matching

# %%
DF.loc[:, "match"] = DF["s"].str.contains("a")

# %%
DF
# Out:
#       s s_0 s_1   s_2  s_3  match
# id
# 0   a_b   a   b  a--b  NaN   True
# 1   B_d   B   d  B--d  NaN  False
# 2   g_H   g   H  g--H  NaN  False

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Timestamps and Time Spans

# %%
# timestamps
pd.Timestamp(2014, 3, 11)
# Out:
# Timestamp('2014-03-11 00:00:00')

# %%
# time spans
pd.Period("2014-03", freq="M")
# Out:
# Period('2014-03', 'M')

# %% [markdown]
# ## Converting to Timestamps

# %%
DF = pd.read_csv("reviews_Grocery_and_Gourmet_Food_5.csv")

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151254 entries, 0 to 151253
# Data columns (total 9 columns):
# asin              151254 non-null object
# helpful           151254 non-null object
# overall           151254 non-null float64
# reviewText        151232 non-null object
# reviewTime        151254 non-null object
# reviewerID        151254 non-null object
# reviewerName      149761 non-null object
# summary           151254 non-null object
# unixReviewTime    151254 non-null int64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 10.4+ MB

# %%
DF.head()["reviewTime"]
# Out:
# 0     06 1, 2013
# 1    05 19, 2014
# 2     10 8, 2013
# 3    05 20, 2013
# 4    05 26, 2013
# Name: reviewTime, dtype: object

# %%
DF.loc[:, "timestamp"] = pd.to_datetime(
    DF["reviewTime"],
    format="%m %d, %Y"
)

# %%
DF.head()[["reviewTime", "timestamp"]]
# Out:
#     reviewTime  timestamp
# 0   06 1, 2013 2013-06-01
# 1  05 19, 2014 2014-05-19
# 2   10 8, 2013 2013-10-08
# 3  05 20, 2013 2013-05-20
# 4  05 26, 2013 2013-05-26

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151254 entries, 0 to 151253
# Data columns (total 10 columns):
# asin              151254 non-null object
# helpful           151254 non-null object
# overall           151254 non-null float64
# reviewText        151232 non-null object
# reviewTime        151254 non-null object
# reviewerID        151254 non-null object
# reviewerName      149761 non-null object
# summary           151254 non-null object
# unixReviewTime    151254 non-null int64
# timestamp         151254 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 11.5+ MB

# %%
DF.set_index("timestamp", inplace=True)

# %%
DF.head()
# Out:
#                   asin helpful  overall  \
# timestamp
# 2013-06-01  616719923X  [0, 0]      4.0
# 2014-05-19  616719923X  [0, 1]      3.0
# 2013-10-08  616719923X  [3, 4]      4.0
# 2013-05-20  616719923X  [0, 0]      5.0
# 2013-05-26  616719923X  [1, 2]      4.0
#
#                                                    reviewText   reviewTime  \
# timestamp
# 2013-06-01  Just another flavor of Kit Kat but the taste i...   06 1, 2013
# 2014-05-19  I bought this on impulse and it comes from Jap...  05 19, 2014
# 2013-10-08  Really good. Great gift for any fan of green t...   10 8, 2013
# 2013-05-20  I had never had it before, was curious to see ...  05 20, 2013
# 2013-05-26  I've been looking forward to trying these afte...  05 26, 2013
#
#                 reviewerID     reviewerName  \
# timestamp
# 2013-06-01  A1VEELTKS8NLZB  Amazon Customer
# 2014-05-19  A14R9XMZVJ6INB          amf0001
# 2013-10-08  A27IQHDZFQFNGG          Caitlin
# 2013-05-20  A31QY5TASILE89     DebraDownSth
# 2013-05-26  A2LWK003FFMCI5         Diana X.
#
#                                                       summary  unixReviewTime
# timestamp
# 2013-06-01                                         Good Taste      1370044800
# 2014-05-19  3.5 stars,  sadly not as wonderful as I had hoped      1400457600
# 2013-10-08                                               Yum!      1381190400
# 2013-05-20                             Unexpected flavor meld      1369008000
# 2013-05-26  Not a very strong tea flavor, but still yummy ...      1369526400

# %%
DF["2013-05-01":"2013-05-02"].head()
# Out:
#                   asin helpful  overall  \
# timestamp
# 2013-05-02  B0002E2GQU  [0, 0]      5.0
# 2013-05-01  B00032G1S0  [4, 4]      5.0
# 2013-05-02  B0004MTMD0  [1, 1]      3.0
# 2013-05-01  B0005XOVY8  [0, 0]      5.0
# 2013-05-01  B0005Z8NCM  [0, 2]      1.0
#
#                                                    reviewText  reviewTime  \
# timestamp
# 2013-05-02  Lavazza produces wonderful coffee and this is ...  05 2, 2013
# 2013-05-01  Finally I found it! THE Tuscan milk....OMG! Ev...  05 1, 2013
# 2013-05-02  This cocoa chile blend was nice and spicy but ...  05 2, 2013
# 2013-05-01  I start my day with a cup of coffee with sugar...  05 1, 2013
# 2013-05-01  The taste of this stuff is sooooo unnatural; I...  05 1, 2013
#
#                 reviewerID           reviewerName  \
# timestamp
# 2013-05-02  A1N7L4DRG7XS2Q    Leslie Heintzberger
# 2013-05-01  A2GA64WZK8PKBC               Cat Feet
# 2013-05-02  A321CGNKNMYU9N  J. Conrad "pandorado"
# 2013-05-01  A25HBMBIBGXCQI   L. Martin "RenoGirl"
# 2013-05-01  A34V43R4VN7OFD               D. Lopez
#
#                                      summary  unixReviewTime
# timestamp
# 2013-05-02           This deserves 10 stars.      1367452800
# 2013-05-01  Great as a facial wash AND bath!      1367366400
# 2013-05-02   Spicy but not chocolatey enough      1367452800
# 2013-05-01      Great Way to Start Your Day!      1367366400
# 2013-05-01                               No!      1367366400

# %% [markdown]
# ## Time/data components

# %%
DF.reset_index(inplace=True)

# %%
DF.head()
# Out:
#    timestamp        asin helpful  overall  \
# 0 2013-06-01  616719923X  [0, 0]      4.0
# 1 2014-05-19  616719923X  [0, 1]      3.0
# 2 2013-10-08  616719923X  [3, 4]      4.0
# 3 2013-05-20  616719923X  [0, 0]      5.0
# 4 2013-05-26  616719923X  [1, 2]      4.0
#
#                                           reviewText   reviewTime  \
# 0  Just another flavor of Kit Kat but the taste i...   06 1, 2013
# 1  I bought this on impulse and it comes from Jap...  05 19, 2014
# 2  Really good. Great gift for any fan of green t...   10 8, 2013
# 3  I had never had it before, was curious to see ...  05 20, 2013
# 4  I've been looking forward to trying these afte...  05 26, 2013
#
#        reviewerID     reviewerName  \
# 0  A1VEELTKS8NLZB  Amazon Customer
# 1  A14R9XMZVJ6INB          amf0001
# 2  A27IQHDZFQFNGG          Caitlin
# 3  A31QY5TASILE89     DebraDownSth
# 4  A2LWK003FFMCI5         Diana X.
#
#                                              summary  unixReviewTime
# 0                                         Good Taste      1370044800
# 1  3.5 stars,  sadly not as wonderful as I had hoped      1400457600
# 2                                               Yum!      1381190400
# 3                             Unexpected flavor meld      1369008000
# 4  Not a very strong tea flavor, but still yummy ...      1369526400

# %%
# .dt accessor of Pandas
DF.loc[:, "review_year"] = DF["timestamp"].dt.year

# %%
DF.head().T
# Out:
#                                                                 0  \
# timestamp                                     2013-06-01 00:00:00
# asin                                                   616719923X
# helpful                                                    [0, 0]
# overall                                                         4
# reviewText      Just another flavor of Kit Kat but the taste i...
# reviewTime                                             06 1, 2013
# reviewerID                                         A1VEELTKS8NLZB
# reviewerName                                      Amazon Customer
# summary                                                Good Taste
# unixReviewTime                                         1370044800
# review_year                                                  2013
#
#                                                                 1  \
# timestamp                                     2014-05-19 00:00:00
# asin                                                   616719923X
# helpful                                                    [0, 1]
# overall                                                         3
# reviewText      I bought this on impulse and it comes from Jap...
# reviewTime                                            05 19, 2014
# reviewerID                                         A14R9XMZVJ6INB
# reviewerName                                              amf0001
# summary         3.5 stars,  sadly not as wonderful as I had hoped
# unixReviewTime                                         1400457600
# review_year                                                  2014
#
#                                                                 2  \
# timestamp                                     2013-10-08 00:00:00
# asin                                                   616719923X
# helpful                                                    [3, 4]
# overall                                                         4
# reviewText      Really good. Great gift for any fan of green t...
# reviewTime                                             10 8, 2013
# reviewerID                                         A27IQHDZFQFNGG
# reviewerName                                              Caitlin
# summary                                                      Yum!
# unixReviewTime                                         1381190400
# review_year                                                  2013
#
#                                                                 3  \
# timestamp                                     2013-05-20 00:00:00
# asin                                                   616719923X
# helpful                                                    [0, 0]
# overall                                                         5
# reviewText      I had never had it before, was curious to see ...
# reviewTime                                            05 20, 2013
# reviewerID                                         A31QY5TASILE89
# reviewerName                                         DebraDownSth
# summary                                    Unexpected flavor meld
# unixReviewTime                                         1369008000
# review_year                                                  2013
#
#                                                                 4
# timestamp                                     2013-05-26 00:00:00
# asin                                                   616719923X
# helpful                                                    [1, 2]
# overall                                                         4
# reviewText      I've been looking forward to trying these afte...
# reviewTime                                            05 26, 2013
# reviewerID                                         A2LWK003FFMCI5
# reviewerName                                             Diana X.
# summary         Not a very strong tea flavor, but still yummy ...
# unixReviewTime                                         1369526400
# review_year                                                  2013

# %%
DF.loc[:, "review_month"] = DF["timestamp"].dt.month
DF.loc[:, "review_day"] = DF["timestamp"].dt.day

# %%
DF.head().T
# Out:
#                                                                 0  \
# timestamp                                     2013-06-01 00:00:00
# asin                                                   616719923X
# helpful                                                    [0, 0]
# overall                                                         4
# reviewText      Just another flavor of Kit Kat but the taste i...
# reviewTime                                             06 1, 2013
# reviewerID                                         A1VEELTKS8NLZB
# reviewerName                                      Amazon Customer
# summary                                                Good Taste
# unixReviewTime                                         1370044800
# review_year                                                  2013
# review_month                                                    6
# review_day                                                      1
#
#                                                                 1  \
# timestamp                                     2014-05-19 00:00:00
# asin                                                   616719923X
# helpful                                                    [0, 1]
# overall                                                         3
# reviewText      I bought this on impulse and it comes from Jap...
# reviewTime                                            05 19, 2014
# reviewerID                                         A14R9XMZVJ6INB
# reviewerName                                              amf0001
# summary         3.5 stars,  sadly not as wonderful as I had hoped
# unixReviewTime                                         1400457600
# review_year                                                  2014
# review_month                                                    5
# review_day                                                     19
#
#                                                                 2  \
# timestamp                                     2013-10-08 00:00:00
# asin                                                   616719923X
# helpful                                                    [3, 4]
# overall                                                         4
# reviewText      Really good. Great gift for any fan of green t...
# reviewTime                                             10 8, 2013
# reviewerID                                         A27IQHDZFQFNGG
# reviewerName                                              Caitlin
# summary                                                      Yum!
# unixReviewTime                                         1381190400
# review_year                                                  2013
# review_month                                                   10
# review_day                                                      8
#
#                                                                 3  \
# timestamp                                     2013-05-20 00:00:00
# asin                                                   616719923X
# helpful                                                    [0, 0]
# overall                                                         5
# reviewText      I had never had it before, was curious to see ...
# reviewTime                                            05 20, 2013
# reviewerID                                         A31QY5TASILE89
# reviewerName                                         DebraDownSth
# summary                                    Unexpected flavor meld
# unixReviewTime                                         1369008000
# review_year                                                  2013
# review_month                                                    5
# review_day                                                     20
#
#                                                                 4
# timestamp                                     2013-05-26 00:00:00
# asin                                                   616719923X
# helpful                                                    [1, 2]
# overall                                                         4
# reviewText      I've been looking forward to trying these afte...
# reviewTime                                            05 26, 2013
# reviewerID                                         A2LWK003FFMCI5
# reviewerName                                             Diana X.
# summary         Not a very strong tea flavor, but still yummy ...
# unixReviewTime                                         1369526400
# review_year                                                  2013
# review_month                                                    5
# review_day                                                     26

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151254 entries, 0 to 151253
# Data columns (total 13 columns):
# timestamp         151254 non-null datetime64[ns]
# asin              151254 non-null object
# helpful           151254 non-null object
# overall           151254 non-null float64
# reviewText        151232 non-null object
# reviewTime        151254 non-null object
# reviewerID        151254 non-null object
# reviewerName      149761 non-null object
# summary           151254 non-null object
# unixReviewTime    151254 non-null int64
# review_year       151254 non-null int64
# review_month      151254 non-null int64
# review_day        151254 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(7)
# memory usage: 15.0+ MB

# %%
DF.to_csv("block_9_data.csv", index=False)
