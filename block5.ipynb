# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#README" data-toc-modified-id="README-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>README</a></span></li><li><span><a href="#Matplotlib" data-toc-modified-id="Matplotlib-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Matplotlib</a></span><ul class="toc-item"><li><span><a href="#The-Basics-of-Matplotlib" data-toc-modified-id="The-Basics-of-Matplotlib-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>The Basics of Matplotlib</a></span></li><li><span><a href="#Editing-Key-Aesthetic-Properties" data-toc-modified-id="Editing-Key-Aesthetic-Properties-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Editing Key Aesthetic Properties</a></span></li><li><span><a href="#Adding-'Textual'-Elements-to-Plots" data-toc-modified-id="Adding-'Textual'-Elements-to-Plots-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Adding 'Textual' Elements to Plots</a></span></li><li><span><a href="#Handling-Subplots" data-toc-modified-id="Handling-Subplots-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Handling Subplots</a></span></li><li><span><a href="#Types-of-Plots" data-toc-modified-id="Types-of-Plots-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Types of Plots</a></span><ul class="toc-item"><li><span><a href="#Histograms" data-toc-modified-id="Histograms-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Histograms</a></span></li><li><span><a href="#Scatter-diagrams" data-toc-modified-id="Scatter-diagrams-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Scatter diagrams</a></span></li><li><span><a href="#Boxplots" data-toc-modified-id="Boxplots-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Boxplots</a></span></li></ul></li><li><span><a href="#From-2-D-to-3-D-Plots" data-toc-modified-id="From-2-D-to-3-D-Plots-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>From 2-D to 3-D Plots</a></span></li></ul></li><li><span><a href="#Bokeh" data-toc-modified-id="Bokeh-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Bokeh</a></span><ul class="toc-item"><li><span><a href="#A-Simple-Example" data-toc-modified-id="A-Simple-Example-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>A Simple Example</a></span></li></ul></li></ul></div>

# %% [markdown]
# # README

# %% [markdown]
# Matplotlib is probably the Python's most popular library for data visualization. Matplotlib is a very flexible tools, allowing users to create and customize an impressive variety of plot 'types'. The best way to appreciate what you can achieve with Matplotlib is going through the [gallery of examples](https://matplotlib.org/gallery/index.html) reported in the website of the library. Personally, I tend to see these examples as a cookbook of plot 'recipes'.
#
# The [Bokeh library](https://bokeh.pydata.org/en/latest/) complements Matplotlib by offering some capabilities for interactive data visualization.

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %% [markdown]
# ## The Basics of Matplotlib

# %% [markdown]
# Argument | Description
# ---------|-------------
# num      | An identifier for the figure―if none is provided, an integer, starting at 1, is used and incremented with each figure created. Alternatively using a string will set the window title to that string when the figure is displayed withplt.show().
# figsize  | A tuple of figure(width, height).
# dpi      | Figure resolution in domts-per-inch.
# facecolor| Figure background color.
# edgecolor| Figure border color.

# %%
# creating the figure
FIG = plt.figure(figsize=(6, 4))

# populate the figure with a plot
AX = FIG.add_subplot(1, 1, 1)

# creating the variables to plot
X = np.linspace(1, 10, 10)
Y = np.square(X)

# plot the data
AX.plot(X, Y)

# display the figure
plt.show()

# %% [markdown]
# ## Editing Key Aesthetic Properties

# %% [markdown]
# Matplotlib color code letters.
#
# Letter | Color
# -------|-----
# b | blue
# g | green
# r | red
# c | cyan
# m | magenta
# y | yellow
# k | black
# w | white

# %% [markdown]
# Line style notations.
#
# Symbol to pass | Outcome
# ----------------------|-----
#  | (no line)
# - | solid
# -- | dashed
# : | dotted
# -. | dash-dot

# %% [markdown]
# Symbol to pass |   Description
# ----------------------|-----------
# . |point
# o | circle
# + | plus
# x | x
# D |diamond
# v |downward triangle
# ^ | upward triangle)
# s | square
# * | star

# %%
# creating the figure
FIG = plt.figure(figsize=(4, 4))

# populate the figure with a plot
AX = FIG.add_subplot(1, 1, 1)

# creating the variables to plot
X = np.linspace(1, 10, 10)
Y = np.square(X)

# plot the data
AX.plot(X, Y, color="b", ls="--", marker="^")

# gridline
AX.grid(linestyle=":", linewidth=2)

# labels
AX.set_xlabel("X - axis")
AX.set_ylabel("Y - axis")

# title
AX.set_title("A title")

# save the figure
FIG.savefig("a_first_plot.pdf")

# display the figure
plt.show()

# close the FIG object
plt.close(FIG)

# %%
# creating the figure
FIG = plt.figure(figsize=(4, 4))

# populate the figure with a plot
AX = FIG.add_subplot(1, 1, 1)

# creating the variables to plot
X = np.linspace(1, 10, 10)
Y = np.square(X)

# plot the data
AX.plot(X, Y, color="b", ls="--", marker="^")

# gridline
AX.grid(linestyle=":", linewidth=1)

# labels
AX.set_xlabel("X - axis")
AX.set_ylabel("Y - axis")

# title
AX.set_title("A title")

# tight layout
FIG.tight_layout()

# save the figure
FIG.savefig("tight_layout.pdf")

# display the figure
plt.show()

# close the FIG object
plt.close(FIG)

# %% [markdown]
# ## Adding 'Textual' Elements to Plots

# %%
# creating the figure
FIG = plt.figure(figsize=(4, 4))

# populate the figure with a plot
AX = FIG.add_subplot(1, 1, 1)

# creating the variables to plot
X = np.linspace(1, 10, 10)
Y = np.square(X)

# plot the data
AX.plot(X, Y, color="b", ls="--", marker="^")

# gridline
AX.grid(linestyle=":", linewidth=1)

# labels
AX.set_xlabel("X - axis")
AX.set_ylabel("Y - axis")

# title
AX.set_title("A title")

# annotations
AX.annotate("A simple comment", xy = (1, 90))

# tight layout
FIG.tight_layout()

# save the figure
# FIG.savefig("tight_layout.pdf")

# display the figure
plt.show()

# close the FIG object
plt.close(FIG)

# %%
# creating the figure
FIG = plt.figure(figsize=(4, 4))

# populate the figure with a plot
AX = FIG.add_subplot(1, 1, 1)

# creating the variables to plot
X = np.linspace(1, 10, 10)
Y = np.square(X)
Y1 = np.sqrt(X)

# plot the data
AX.plot(X, Y, color="b", ls="", marker="^", label="Square")
AX.plot(X, Y1, color="red", ls="", marker="v", label="Square root")

# legend
AX.legend(loc="best")

# gridline
AX.grid(linestyle=":", linewidth=1)

# labels
AX.set_xlabel("X - axis")
AX.set_ylabel("Y - axis")

# title
AX.set_title("A title")

# annotations
# AX.annotate("A simple comment", xy = (1, 90))

# tight layout
FIG.tight_layout()

# save the figure
# FIG.savefig("tight_layout.pdf")

# display the figure
plt.show()

# close the FIG object
plt.close(FIG)

# %% [markdown]
# ## Handling Subplots

# %%
# creating the figure
FIG = plt.figure(figsize=(8, 4))

# populate the figure with a plot
AX0 = FIG.add_subplot(1, 2, 1)
AX1 = FIG.add_subplot(1, 2, 2)

# creating the variables to plot
X = np.linspace(1, 10, 10)
Y = np.square(X)
Y1 = np.sqrt(X)

# plot the data
AX0.plot(X, Y, color="b", ls="", marker="^", label="Square")
AX1.plot(X, Y1, color="red", ls="", marker="v", label="Square root")

# gridline
AX0.grid(linestyle=":", linewidth=1)
AX1.grid(linestyle=":", linewidth=1)

# labels
AX0.set_xlabel("X - axis")
AX0.set_ylabel("Y - axis")
AX1.set_xlabel("X - axis")
AX1.set_ylabel("Y - axis")

# tight layout
FIG.tight_layout()

# save the figure
# FIG.savefig("tight_layout.pdf")

# display the figure
plt.show()

# close the FIG object
plt.close(FIG)

# %%
# creating the figure
FIG = plt.figure(figsize=(4, 8))

# populate the figure with a plot
AX0 = FIG.add_subplot(2, 1, 1)
AX1 = FIG.add_subplot(2, 1, 2)

# creating the variables to plot
X = np.linspace(1, 10, 10)
Y = np.square(X)
Y1 = np.sqrt(X)

# plot the data
AX0.plot(X, Y, color="b", ls="", marker="^", label="Square")
AX1.plot(X, Y1, color="red", ls="", marker="v", label="Square root")

# gridline
AX0.grid(linestyle=":", linewidth=1)
AX1.grid(linestyle=":", linewidth=1)

# labels
AX0.set_xlabel("X - axis")
AX0.set_ylabel("Y - axis")
AX1.set_xlabel("X - axis")
AX1.set_ylabel("Y - axis")

# tight layout
FIG.tight_layout()

# save the figure
# FIG.savefig("tight_layout.pdf")

# display the figure
plt.show()

# close the FIG object
plt.close(FIG)

# %% [markdown]
# ## Types of Plots

# %% [markdown]
# ### Histograms

# %%
# creating a new figure
FIG = plt.figure(figsize=(4, 4))

# populate the figure with a plot
AX = FIG.add_subplot(1, 1, 1)

# simulate some data
np.random.seed(000)
X = np.random.randn(100)

# plot the data
AX.hist(X, bins=20)

# display the plot
plt.show()

# close the figure
plt.close(FIG)

# %%
# creating a new figure
FIG = plt.figure(figsize=(4, 4))

# populate the figure with a plot
AX = FIG.add_subplot(1, 1, 1)

# simulate some data
np.random.seed(000)
X0 = np.random.randn(100)
X1 = np.random.normal(1, 1, 100)

# plot the data
AX.hist(X0, bins=20, color="b", alpha=0.20)
AX.hist(X1, bins=20, color="g", alpha=0.30)

# display the plot
plt.show()

# close the figure
plt.close(FIG)

# %% [markdown]
# ### Scatter diagrams

# %%
# create a figure
FIG = plt.figure(figsize=(4, 4))

# populate the figure with a plot
AX = FIG.add_subplot(1, 1, 1)

# create the data to plot
np.random.seed(000)
X0 = np.random.randn(100)
X1 = np.random.normal(1, 1, 100)

# plot the data
AX.scatter(X0, X1)

# display the plot
plt.show()

# close the figure
plt.close(FIG)

# %%
# create a figure
FIG = plt.figure(figsize=(4, 4))

# populate the figure with a plot
AX = FIG.add_subplot(1, 1, 1)

# create the data to plot
np.random.seed(000)
X0 = np.random.randn(100)
X1 = np.random.normal(1, 1, 100)
Y = np.random.randint(1, 10, 100)
Z = np.random.poisson(12, 100) ** 2

# plot the data
AX.scatter(X0, X1, c=Y, s=Z, alpha=0.4)

# display the plot
plt.show()

# close the figure
plt.close(FIG)

# %% [markdown]
# ### Boxplots

# %%
# figure
FIG = plt.figure(figsize=(4, 4))

# plot
AX = FIG.add_subplot(111)

# plot the data
AX.boxplot([X0, X1])

# xtick labels
AX.set_xticklabels(("X0", "X1"))

# axhline
AX.axhline(y = 0, color = "r")

# display the plot
plt.show()

# close the figure
plt.close(FIG)

# %% [markdown]
# ## From 2-D to 3-D Plots

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure()
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)

# Plot the 3D surface
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)

# Plot projections of the contours for each dimension.  By choosing offsets
# that match the appropriate axes limits, the projected contours will sit on
# the 'walls' of the graph
cset = ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlim(-40, 40)
ax.set_ylim(-40, 40)
ax.set_zlim(-100, 100)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %% [markdown]
# # Bokeh

# %% [markdown]
# ## A Simple Example

# %% [markdown]
# See [tutorial 01](https://mybinder.org/v2/gh/bokeh/bokeh-notebooks/master?filepath=tutorial%2F00%20-%20Introduction%20and%20Setup.ipynb), prepared by the Bokeh team.

# %% [markdown]
# Problem Set

# %%
# creating a new figure
FIG = plt.figure(figsize=(20, 6))

# populate the figure with a plot
AX1 = FIG.add_subplot(1, 3, 1)
AX2 = FIG.add_subplot(1, 3, 2)
AX3 = FIG.add_subplot(1, 3, 3)

# simulate some data
np.random.seed(000)
X1 = np.random.randn(100)
X2 = np.random.normal(1,2,100)

# plot the data
AX1.hist(X1, bins=20)
AX2.scatter(X1,X2)
AX3.boxplot([X1, X2])
AX3.set_xticklabels(("X0", "X1"))

# display the plot
plt.show()

# close the figure
plt.close(FIG)
